# %% [markdown]
#  See results_notebook.py for a more complicated analysis example (used to replicate some analyses from a previous SERP-related paper).
#
#  This file is meant to provide a very quick starting point for writing up other analyses.

# %% [markdown]
#  # Current data format
#  Currently, the node.js scraping code (see collect.js)
#  saves 3 result files per SERP scraped:
#  * a .json file with
#  device object used by puppeteer ("device"), date collection started ("dateStr"),
#  date of collection ("dataAtSave"), user-specified query category (queryCat),
#  file queries came from ("queryFile"), device name ("deviceName"),
#  url accessed ("link"), the search engine or website ("platform"),
#  the query made ("target"), and finally, a huge array of link elements ("linkElements")
#  * a .png file that is a full screenshot of the SERP
#  * a .mhtml snapshot of the website that can be opened in a web browser (this is experimental, apparently)
#
#  Files are named by datetime of script start to avoid accidental overwrite.
#
#  This script (analysis.py) includes code which stitches together a visual representation of
#  links and their coordinates (obtained using getBoundingClientRect) alongside screenshots
#  so search can perform visual validation -- compare the link representation (easy to do quant analyses)
#  with the png representation and make sure they match up!

# %% [markdown]
#  we'll use pandas and friends for this quick analysis.

# %%
# defaults
import json
import glob
from pprint import pprint
from collections import defaultdict
from urllib.parse import unquote
import os

# scipy
import pandas as pd
import numpy as np

# plotting / images
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from PIL import Image

# helpers for this project
from helpers import (
    infinite_defaultdict, recurse_print_infinitedict, extract,
    is_mobile,
)
from constants import CONSTANTS

DO_COORDS = False
SAVE_PLOTS = False

# %%
# new data will be in results/*. This is an example!
filename = 'nov5_example/Chrome on Windows/https---www.google.com-search?q=protests/Thu Nov 05 2020 14-12-08 GMT-0600 (Central Standard Time).json'
with open(filename, 'r', encoding='utf8') as f:
    d = json.load(f)
d.keys()
# Out:
# dict_keys(['device', 'dateStr', 'linkElements', 'queryCat', 'queryFile', 'errMsg', 'deviceName', 'link', 'platform', 'target', 'dateAtSave'])

# %%
# print all details except the actual links (which is huge)
{k: v for k, v in d.items() if k != 'linkElements'}
# Out:
# {'dateAtSave': 'Thu Nov 05 2020 14:12:25 GMT-0600 (Central Standard Time)',
#  'dateStr': 'Thu Nov 05 2020 14:12:08 GMT-0600 (Central Standard Time)',
#  'device': {'name': 'Chrome on Windows',
#   'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36',
#   'viewport': {'height': 768, 'width': 1024}},
#  'deviceName': 'Chrome on Windows',
#  'errMsg': '',
#  'link': 'https://www.google.com/search?q=protests',
#  'platform': 'google',
#  'queryCat': 'test',
#  'queryFile': 0,
#  'target': 'protests'}

# %%
df = pd.DataFrame(d['linkElements'])
df.head()
# Out:
#     top    left  bottom   right  \
# 0  64.0    11.0   108.0   121.0
# 1  64.0    11.0   108.0   121.0
# 2  86.0    11.0   130.0   121.0
# 3  24.0  1085.0    64.0  1125.0
# 4  26.0  1137.0    62.0  1233.0
#
#                                                 href  \
# 0
# 1  https://support.google.com/websearch/answer/18...
# 2
# 3  https://www.google.com/intl/en/about/products?...
# 4  https://accounts.google.com/ServiceLogin?hl=en...
#
#                                           parentText parentClasses  \
# 0  Skip to main contentAccessibility helpa.duf3{c...      [S6VXfe]
# 1  Skip to main contentAccessibility helpa.duf3{c...      [S6VXfe]
# 2  a.duf3{color:#70757a;float:right;font-style:it...            []
# 3                                                          [gb_Vf]
# 4                                            Sign in       [gb_5e]
#
#                       classes                    text
# 0                    [gyPpGe]    Skip to main content
# 1                    [gyPpGe]      Accessibility help
# 2                    [gyPpGe]  Accessibility feedback
# 3                      [gb_D]
# 4  [gb_4, gb_5, gb_le, gb_8c]                 Sign in

# %%
from analyze_links import analyze_links_df
analyzed = analyze_links_df(df)
analyzed.head()
# Out:
#     top    left  bottom   right  \
# 0  64.0    11.0   108.0   121.0
# 1  64.0    11.0   108.0   121.0
# 2  86.0    11.0   130.0   121.0
# 3  24.0  1085.0    64.0  1125.0
# 4  26.0  1137.0    62.0  1233.0
#
#                                                 href  \
# 0
# 1  https://support.google.com/websearch/answer/18...
# 2
# 3  https://www.google.com/intl/en/about/products?...
# 4  https://accounts.google.com/ServiceLogin?hl=en...
#
#                                           parentText parentClasses  \
# 0  Skip to main contentAccessibility helpa.duf3{c...      [S6VXfe]
# 1  Skip to main contentAccessibility helpa.duf3{c...      [S6VXfe]
# 2  a.duf3{color:#70757a;float:right;font-style:it...            []
# 3                                                          [gb_Vf]
# 4                                            Sign in       [gb_5e]
#
#                       classes                    text  width  ...  reddit_in  \
# 0                    [gyPpGe]    Skip to main content  110.0  ...      False
# 1                    [gyPpGe]      Accessibility help  110.0  ...      False
# 2                    [gyPpGe]  Accessibility feedback  110.0  ...      False
# 3                      [gb_D]                           40.0  ...      False
# 4  [gb_4, gb_5, gb_le, gb_8c]                 Sign in   96.0  ...      False
#
#    reddit_appears  reddit_appears_rh  reddit_appears_lh  \
# 0           False              False              False
# 1           False              False              False
# 2           False              False              False
# 3           False              False              False
# 4           False              False              False
#
#    reddit_appears_noscroll_lb  reddit_appears_lh_noscroll_lb  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
#
#    reddit_appears_noscroll_mg reddit_appears_lh_noscroll_mg  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
#
#    reddit_appears_noscroll_ub  reddit_appears_lh_noscroll_ub
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
#
# [5 rows x 69 columns]

# %%
analyzed.domain.value_counts()
# Out:
# www.google.com                    74
# en.wikipedia.org                   5
# support.google.com                 4
#                                    4
# webcache.googleusercontent.com     3
# www.foxnews.com                    3
# policies.google.com                2
# apnews.com                         2
# www.nytimes.com                    2
# www.cnn.com                        2
# www.youtube.com                    2
# accounts.google.com                1
# nypost.com                         1
# www.azfamily.com                   1
# maps.google.com                    1
# www.aljazeera.com                  1
# www.washingtonpost.com             1
# www.buzzfeednews.com               1
# economictimes.indiatimes.com       1
# www.cbsnews.com                    1
# www.usatoday.com                   1
# www.aeinstein.org                  1
# denver.cbslocal.com                1
# Name: domain, dtype: int64

# %%
tmp = analyzed.sort_values('top')[['top', 'left', 'domain', 'href']]
# drop "google" domains
tmp[~tmp.domain.str.contains('google')]
# Out:
#              top       left                        domain  \
# 108     0.000000     0.0000
# 0      64.000000    11.0000
# 11     75.000000   561.3125
# 2      86.000000    11.0000
# 39    212.000000  2161.0000                    nypost.com
# 38    212.000000  1941.0000               www.cbsnews.com
# 37    212.000000  1721.0000               www.foxnews.com
# 35    212.000000  1281.0000               www.nytimes.com
# 34    212.000000  1061.0000           denver.cbslocal.com
# 33    212.000000   841.0000              www.usatoday.com
# 32    212.000000   621.0000             www.aljazeera.com
# 31    212.000000   401.0000                    apnews.com
# 30    212.000000   181.0000               www.foxnews.com
# 36    212.000000  1501.0000                   www.cnn.com
# 41    617.000000   181.0000               www.youtube.com
# 42    708.000000   181.0000  economictimes.indiatimes.com
# 43    799.000000   181.0000                   www.cnn.com
# 44    890.000000   181.0000               www.youtube.com
# 47   1099.000000   180.0000               www.nytimes.com
# 51   1471.000000   197.0000             www.aeinstein.org
# 58   1506.000000   180.0000                    apnews.com
# 53   1515.000000   197.0000              en.wikipedia.org
# 48   1559.000000   197.0000              en.wikipedia.org
# 55   1581.000000   197.0000              en.wikipedia.org
# 61   1643.000000   180.0000               www.foxnews.com
# 49   1643.000000   197.0000              en.wikipedia.org
# 79   2059.765625   180.0000              en.wikipedia.org
# 83   2196.765625   180.0000        www.washingtonpost.com
# 84   2355.765625   180.0000          www.buzzfeednews.com
# 87   2492.765625   180.0000              www.azfamily.com
#
#                                                   href
# 108
# 0
# 11
# 2
# 39   https://nypost.com/2020/11/05/woman-charged-wi...
# 38   https://www.cbsnews.com/video/pro-president-tr...
# 37   https://www.foxnews.com/us/nypd-charge-protest...
# 35   https://www.nytimes.com/2020/11/05/us/election...
# 34   https://denver.cbslocal.com/2020/11/05/riots-d...
# 33   https://www.usatoday.com/story/news/investigat...
# 32   https://www.aljazeera.com/news/2020/11/5/alger...
# 31   https://apnews.com/article/trump-backers-conve...
# 30   https://www.foxnews.com/us/live-updates-nation...
# 36   https://www.cnn.com/videos/politics/2020/11/05...
# 41         https://www.youtube.com/watch?v=47qZZw1Z3i4
# 42   https://economictimes.indiatimes.com/news/inte...
# 43   https://www.cnn.com/videos/politics/2020/11/05...
# 44         https://www.youtube.com/watch?v=dNRljCbzsfY
# 47   https://www.nytimes.com/2020/11/05/us/election...
# 51   https://www.aeinstein.org/nonviolentaction/198...
# 58   https://apnews.com/article/trump-backers-conve...
# 53   https://en.wikipedia.org/wiki/15_February_2003...
# 48   https://en.wikipedia.org/wiki/List_of_protests...
# 55   https://en.wikipedia.org/wiki/Causes_of_the_20...
# 61     https://www.foxnews.com/category/us/us-protests
# 49   https://en.wikipedia.org/wiki/List_of_protests...
# 79               https://en.wikipedia.org/wiki/Protest
# 83   https://www.washingtonpost.com/nation/2020/07/...
# 84   https://www.buzzfeednews.com/collection/2020pr...
# 87   https://www.azfamily.com/news/politics/electio...
